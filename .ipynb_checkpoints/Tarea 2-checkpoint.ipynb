# %% [markdown]
# # 📊 Práctica: Uso de RDD en PySpark con Archivos Parquet (NYC Taxi 2025)
#
# ## 🎯 Objetivo
#
# El objetivo de esta práctica es:
#
# 1. Obtener información desde un origen de datos externo.
# 2. Convertir dicho origen a un RDD utilizando PySpark.
# 3. Realizar operaciones básicas sobre el RDD (estadísticas descriptivas).
# 4. Documentar y subir la práctica a un repositorio público en GitHub.
#
# ---
#
# ## 📂 Origen de Datos
#
# Para esta práctica se utilizaron archivos en formato **Parquet** correspondientes al dataset público de taxis de Nueva York (NYC Yellow Taxi).
#
# Archivos utilizados:
#
# - `yellow_tripdata_2025-01.parquet`
# - `yellow_tripdata_2025-02.parquet`
# - `yellow_tripdata_2025-03.parquet`
#
# Estos archivos contienen información detallada sobre viajes realizados, incluyendo variables numéricas y categóricas.
#
# Columnas utilizadas en el análisis:
#
# - `trip_distance` → Distancia del viaje.
# - `fare_amount` → Monto cobrado por el viaje.
# - `payment_type` → Tipo de pago utilizado.
#
# ---
#
# ## 🔄 Proceso Realizado
#
# ### 1️⃣ Carga de Datos
#
# Los archivos Parquet fueron cargados utilizando `SparkSession.read.parquet()`, generando un DataFrame de Spark.
#
# Posteriormente se realizó:
#
# - Selección de columnas relevantes.
# - Eliminación de valores nulos.
# - Filtrado de registros con valores mayores a cero.
# - Cache del DataFrame para optimizar las operaciones posteriores.
#
# ---
#
# ### 2️⃣ Conversión a RDD
#
# El DataFrame filtrado fue convertido a RDD mediante:
#
# ```python
# rdd = df_filtrado.rdd

# %%
# ============================================================
# PRÁCTICA: RDD EN PYSPARK (ESTADÍSTICAS DESCRIPTIVAS BÁSICAS)
# Fuente: NYC Taxi (Parquet) - Yellow Tripdata (2025-01..03)
# ============================================================

import os, sys
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# ===============================
# 0) SPARK SESSION (tu configuración)
# ===============================
os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

spark = (
    SparkSession.builder
    .master("local[*]")
    .appName("PRACTICA_RDD_PYSPARK")
    .config("spark.driver.bindAddress", "127.0.0.1")
    .config("spark.driver.host", "127.0.0.1")
    .config("spark.driver.extraJavaOptions", "-Djava.net.preferIPv4Stack=true")
    .config("spark.executor.extraJavaOptions", "-Djava.net.preferIPv4Stack=true")
    # estabilidad
    .config("spark.python.worker.faulthandler.enabled", "true")
    .config("spark.sql.execution.pyspark.udf.faulthandler.enabled", "true")
    .config("spark.python.worker.reuse", "true")
    .config("spark.sql.execution.arrow.pyspark.enabled", "false")
    .getOrCreate()
)

print("Spark listo ✅")
print("Python:", sys.executable)

# ===============================
# 1) CARGA DE LOS ARCHIVOS PARQUET
# ===============================
ruta_base = r"C:\Users\Oscar Ferreira\OneDrive - AUTO LINEAS AMERICA SA DE CV\Escritorio\MCD\6 - DATOS MASIVOS"

df = spark.read.parquet(
    f"{ruta_base}/yellow_tripdata_2025-01.parquet",
    f"{ruta_base}/yellow_tripdata_2025-02.parquet",
    f"{ruta_base}/yellow_tripdata_2025-03.parquet"
)

print("DataFrame cargado correctamente ✅")
print("Columnas disponibles:", df.columns)

# ===============================
# 2) SELECCIÓN DE COLUMNAS + LIMPIEZA MÍNIMA
# ===============================
# Usamos exactamente lo que pusimos en el Markdown:
# - trip_distance (numérica)
# - fare_amount (numérica)
# - payment_type (categórica)

cols = ["trip_distance", "fare_amount", "payment_type"]
faltantes = [c for c in cols if c not in df.columns]
if faltantes:
    raise ValueError(f"Faltan columnas necesarias: {faltantes}")

df_filtrado = (
    df.select(*cols)
      .filter(F.col("trip_distance").isNotNull())
      .filter(F.col("fare_amount").isNotNull())
      .filter(F.col("payment_type").isNotNull())
      .filter(F.col("trip_distance") > 0)
      .filter(F.col("fare_amount") > 0)
)

# Cache para estabilizar y acelerar acciones posteriores
df_filtrado = df_filtrado.cache()

# Acción "segura" para materializar cache
n_df = df_filtrado.count()
print(f"DataFrame filtrado y cacheado ✅ | Registros válidos: {n_df:,}")

# ===============================
# 3) CONVERSIÓN A RDD
# ===============================
rdd = df_filtrado.rdd  # RDD de Rows

print("\nRDD creado ✅")
print("Tipo:", type(rdd))

# Evita take(5) si no es necesario; pero ya lo probaste y funciona.
ejemplo = rdd.take(5)
print("Ejemplo (5 filas):")
for row in ejemplo:
    print(row)

# ===============================
# 4) OPERACIONES EN RDD (ESTADÍSTICAS DESCRIPTIVAS BÁSICAS)
# ===============================

# 4.1 Conteo total
total_registros = rdd.count()
print("\n1) Conteo total de registros (RDD):", f"{total_registros:,}")

# 4.2 Estadísticas básicas para fare_amount
rdd_fare = rdd.map(lambda x: float(x["fare_amount"]))

min_fare = rdd_fare.min()
max_fare = rdd_fare.max()
sum_fare = rdd_fare.sum()
avg_fare = sum_fare / total_registros if total_registros else float("nan")

print("\n2) Estadísticas básicas (fare_amount):")
print("   - Mínimo:", round(min_fare, 2))
print("   - Máximo:", round(max_fare, 2))
print("   - Promedio:", round(avg_fare, 2))

# 4.3 Estadísticas básicas para trip_distance
rdd_dist = rdd.map(lambda x: float(x["trip_distance"]))

min_dist = rdd_dist.min()
max_dist = rdd_dist.max()
sum_dist = rdd_dist.sum()
avg_dist = sum_dist / total_registros if total_registros else float("nan")

print("\n   Estadísticas básicas (trip_distance):")
print("   - Mínimo:", round(min_dist, 3))
print("   - Máximo:", round(max_dist, 3))
print("   - Promedio:", round(avg_dist, 3))

# 4.4 Conteo por categoría (payment_type)
conteo_payment_type = (
    rdd.map(lambda x: (int(x["payment_type"]), 1))
       .reduceByKey(lambda a, b: a + b)
       .collect()
)

conteo_payment_type_ordenado = sorted(conteo_payment_type, key=lambda t: t[1], reverse=True)

print("\n3) Conteo por payment_type (desc):")
for k, v in conteo_payment_type_ordenado:
    print(f"   - payment_type={k}: {v:,}")

# 4.5 Top N por fare_amount
top_n = 10
top_fares = (
    rdd.map(lambda x: (float(x["fare_amount"]), float(x["trip_distance"]), int(x["payment_type"])))
       .takeOrdered(top_n, key=lambda t: -t[0])   # descendente por fare_amount
)

print(f"\n4) Top {top_n} registros por fare_amount:")
for i, (fare, dist, pay) in enumerate(top_fares, start=1):
    print(f"   {i:02d}) fare_amount={fare:.2f} | trip_distance={dist:.3f} | payment_type={pay}")



# ===============================
# 6) CERRAR SPARK
# ===============================
spark.stop()
print("\nSpark detenido ✅")
# Out:
# Spark listo ✅
# Python: C:\Users\Oscar Ferreira\venv_pyspark\Scripts\python.exe
# DataFrame cargado correctamente ✅
# Columnas disponibles: ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'Airport_fee', 'cbd_congestion_fee']
# DataFrame filtrado y cacheado ✅ | Registros válidos: 10,413,352
#
# RDD creado ✅
# Tipo: <class 'pyspark.core.rdd.RDD'>
# Ejemplo (5 filas):
# Row(trip_distance=1.6, fare_amount=10.0, payment_type=1)
# Row(trip_distance=0.5, fare_amount=5.1, payment_type=1)
# Row(trip_distance=0.6, fare_amount=5.1, payment_type=1)
# Row(trip_distance=0.52, fare_amount=7.2, payment_type=2)
# Row(trip_distance=0.66, fare_amount=5.8, payment_type=2)
#
# 1) Conteo total de registros (RDD): 10,413,352
#
# ...
